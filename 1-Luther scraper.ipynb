# %% [markdown]
# # Luther Project: NBA STATS scraper

# %%
#imports
import requests
from bs4 import BeautifulSoup
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import OrderedDict
import pickle
import random
import time


# %matplotlib inline
sns.set()

# %%
# #test urls
# url = 'https://www.basketball-reference.com/players/n/nowitdi01.html' #drafted, many years experience
# url2 = 'https://www.basketball-reference.com/players/b/bareajo01.html' #undrafted, multiyear contract, multiple teams
# url3 = 'https://www.basketball-reference.com/players/m/motlejo01.html' #undrafted, few years of exp
# url4 = 'https://www.basketball-reference.com/players/b/bryanko01.html' #retired 
# url5 = 'https://www.basketball-reference.com/players/a/abrinal01.html' 
# url6 = 'https://www.basketball-reference.com/players/a/asikom01.html' #traded 
# url7 = 'https://www.basketball-reference.com/players/b/bookede01.html'
# url8 = 'https://www.basketball-reference.com/players/b/brookma01.html'
# url9 = 'https://www.basketball-reference.com/players/v/vanvlfr01.html'

# urls = [url, url2, url3, url4, url5, url6, url7, url8, url9]

# %%
def clean_html(url):
    """consolidate getting and cleaning html"""
    response = requests.get(url)
    #print(response.status_code)
    page = response.text.replace('<!--', '').replace('-->', '') # tables were hidden in comment tags
    soup = BeautifulSoup(page, 'lxml')
    return soup

# %%
# #generate test soups
# soups = [clean_html(url) for url in urls]

# %% [markdown]
# # Parsing for bio / static information

# %%
def find_name(soup):
    """player name"""
    return soup.find('div', id='meta').find('h1').text

def find_height(soup):
    """in inches"""
    ft_in = soup.find('div', id='meta').find(attrs={'itemprop': 'height'}).text.split('-')
    return 12*int(ft_in[0]) + int(ft_in[1])

def find_weight(soup):
    """in pounds"""
    return int(soup.find('div', id='meta').find(attrs={'itemprop': 'weight'}).text[:-2])
        
def find_draft_position(soup):
    """returns 0 if undrafted"""
    overall = soup.find('div', id='meta').find(text=re.compile('overall'))
    if overall:
        return int(overall.split()[-2][:-2])
    else:
        return 0 # for undrafted # would this make ranks out of order? 
    
def career_earnings(soup):
    if soup.find("table", id='all_salaries'):
        return int(soup.find("table", id='all_salaries').find("tfoot").find_all('td')[-1].text.replace('$','').replace(',',''))
    else:
        return 0 #no career earnings 
    
def find_bio(soup):
    """consolidated bio function"""
    return [find_name(soup), find_height(soup), find_weight(soup), find_draft_position(soup), career_earnings(soup)]

def find_career_stats(soup):
    """includes stats for future years """
    basics_raw = soup.find("table", id="per_game").find("tfoot").find_all('tr')[0].find_all('td')
    basics = [col.text for col in basics_raw]

    advanced = [col.text for col in (soup.find("table", id="advanced").find('tfoot')
                                           .find_all('tr')[0].find_all('td'))]

    return basics + advanced

# %% [markdown]
# # Parse season specific information

# %%
def find_current_salary(soup, y):
    """0 if no known contract"""
    is_active = soup.find("table", id=re.compile('contracts')) #might need better way of checking
    if is_active:
        if not is_active.td.text: #check for no contract
            return '0'
        elif y == 1: #looks at contract table
            return is_active.find_all('td')[y].text
        elif soup.find("table", id='all_salaries'): #looks at salary table if it exists
        #    return soup.find("table", id="all_salaries").find_all('tr')[-y].find_all('td')[-1].text
            try: # catch errors with missing salary info
                return soup.find("table", id="all_salaries").find_all('tr')[-y].find_all('td')[-1].text
            except IndexError:
                return '0'
        else:
            return '0'
    elif soup.find("table", id="all_salaries"):
        try:
            return soup.find("table", id="all_salaries").find('tbody').find_all('tr')[-y].find_all('td')[-1].text
        except IndexError:
            return '0'
    else:
        return '0'

def find_season_stats(soup, y=1):
    """where y describes how recent the season is(1 being most recent)
    returns as a single list of:
        current season basic stats, advanced stats, and salary"""
    
    basic_rows = soup.find("table", id="per_game").find('tbody').find_all('tr', attrs={'class':'full_table'}) #basic
 
    career_length = len(basic_rows)
    years_exp =  career_length - (y-1) 

    if years_exp <= 0: #if wasn't in league
        return [np.NaN] * 60 #season stats= list of nulls
    
    current_year = soup.find("table", id="per_game").find("tbody").find_all('tr', attrs={'class':'full_table'})[-y].find('th').text
    basic_stats = [current_year, years_exp]
    for col in basic_rows[-y].find_all('td'): #looking at latest season
        basic_stats.append(col.text)

    advanced_stats = [col.text for col in (soup.find("table", id="advanced").find('tbody')
                                           .find_all('tr',attrs={'class':'full_table'})[-y].find_all('td'))]

    salary = [int(find_current_salary(soup, y).replace('$','').replace(',',''))] #numeric salary
    return basic_stats + advanced_stats + salary

# %%
#soup = clean_html('https://www.basketball-reference.com/players/t/thomala01.html')
# y =  3
#soup.find("table", id="all_salaries").find('tbody').find_all('tr')[-y].find_all('td')[-1].text

# %%
# soups[4].find("table", id="per_game").find("tbody").find_all('th',{'scope':'row', 'data-stat':'season'})[-2].text

# %%
#soups[5].find("table", id="per_game").find("tbody").find_all('tr', attrs={'class':'full_table'})[-3].find('th').text

# %% [markdown]
# # Create dictionary of col names to data

# %%
def label(stats):
    col_names = ['Name', 'Height', 'Weight', 'Draft Position', 'Career Earnings', 'Current Season(C)', 'C_Experience', 'C_Age', 'C_Tm', 'C_Lg', 'C_Pos', 'C_G', 'C_GS', 'C_MP', 'C_FG', 'C_FGA', 'C_FG%', 'C_3P', 'C_3PA', 'C_3P%', 'C_2P', 'C_2PA', 'C_2P%', 'C_eFG%', 'C_FT', 'C_FTA', 'C_FT%', 'C_ORB', 'C_DRB', 'C_TRB', 'C_AST', 'C_STL', 'C_BLK', 'C_TOV', 'C_PF', 'C_PTS', 'C_Age', 'C_Tm', 'C_Lg', 'C_Pos', 'C_G', 'C_MP', 'C_PER', 'C_TS%', 'C_3PAr', 'C_FTr', 'C_ORB%', 'C_DRB%', 'C_TRB%', 'C_AST%', 'C_STL%', 'C_BLK%', 'C_TOV%', 'C_USG%', 'C_\xa0', 'C_OWS', 'C_DWS', 'C_WS', 'C_WS/48', 'C_\xa0', 'C_OBPM', 'C_DBPM', 'C_BPM', 'C_VORP', 'C_Salary', 'Prev_Season(P)', 'P_Experience', 'P_Age', 'P_Tm', 'P_Lg', 'P_Pos', 'P_G', 'P_GS', 'P_MP', 'P_FG', 'P_FGA', 'P_FG%', 'P_3P', 'P_3PA', 'P_3P%', 'P_2P', 'P_2PA', 'P_2P%', 'P_eFG%', 'P_FT', 'P_FTA', 'P_FT%', 'P_ORB', 'P_DRB', 'P_TRB', 'P_AST', 'P_STL', 'P_BLK', 'P_TOV', 'P_PF', 'P_PTS', 'P_Age', 'P_Tm', 'P_Lg', 'P_Pos', 'P_G', 'P_MP', 'P_PER', 'P_TS%', 'P_3PAr', 'P_FTr', 'P_ORB%', 'P_DRB%', 'P_TRB%', 'P_AST%', 'P_STL%', 'P_BLK%', 'P_TOV%', 'P_USG%', 'P_\xa0', 'P_OWS', 'P_DWS', 'P_WS', 'P_WS/48', 'P_\xa0', 'P_OBPM', 'P_DBPM', 'P_BPM', 'P_VORP', 'P_Salary', 'Ca_Age', 'Ca_Tm', 'Ca_Lg', 'Ca_Pos', 'Ca_G', 'Ca_GS', 'Ca_MP', 'Ca_FG', 'Ca_FGA', 'Ca_FG%', 'Ca_3P', 'Ca_3PA', 'Ca_3P%', 'Ca_2P', 'Ca_2PA', 'Ca_2P%', 'Ca_eFG%', 'Ca_FT', 'Ca_FTA', 'Ca_FT%', 'Ca_ORB', 'Ca_DRB', 'Ca_TRB', 'Ca_AST', 'Ca_STL', 'Ca_BLK', 'Ca_TOV', 'Ca_PF', 'Ca_PTS', 'Ca_Age', 'Ca_Tm', 'Ca_Lg', 'Ca_Pos', 'Ca_G', 'Ca_MP', 'Ca_PER', 'Ca_TS%', 'Ca_3PAr', 'Ca_FTr', 'Ca_ORB%', 'Ca_DRB%', 'Ca_TRB%', 'Ca_AST%', 'Ca_STL%', 'Ca_BLK%', 'Ca_TOV%', 'Ca_USG%', 'Ca_\xa0', 'Ca_OWS', 'Ca_DWS', 'Ca_WS', 'Ca_WS/48', 'Ca_\xa0', 'Ca_OBPM', 'Ca_DBPM', 'Ca_BPM', 'Ca_VORP']
    if len(col_names) != len(stats):
        print(stats[0]) # print name for player pages that didn't parse properly
    return OrderedDict(zip(col_names, stats))

# %% [markdown]
# # Create list of dicts to become rows in dataframe

# %%
def make_rows(soup):
    """input soup page,
    output: up to 3 rows per player
    r#s means reverse"""
    print(find_name(soup))
    basic_rows = soup.find("table", id="per_game").find('tbody').find_all('tr', attrs={'class':'full_table'}) #basic
    years_exp = len(basic_rows)
 
    #generate static data - will be repeated for same player
    bio = find_bio(soup) 
    career = find_career_stats(soup)

    #decide how many rows to make
    if years_exp == 1:
        r1_season = bio + find_season_stats(soup, 1) + find_season_stats(soup, 2) + career
        return [label(r1_season)]
    
    if years_exp == 2:
        b = find_season_stats(soup, 2)
        r1_season = bio + find_season_stats(soup, 1) + b + career
        r2_season = bio + b + find_season_stats(soup, 3) + career
        return [label(r1_season), label(r2_season)] #list of dicts
    
    if years_exp >= 3:
        b = find_season_stats(soup, 2)
        c = find_season_stats(soup, 3)
        r1_season = bio + find_season_stats(soup, 1) + b + career
        r2_season = bio + b + c + career
        r3_season = bio + c + find_season_stats(soup, 4) + career
        return [label(r1_season), label(r2_season), label(r3_season)]

# %%
# dictlist = []
# for soup in soups:
#     dictlist.extend(make_rows(soup))
# pd.DataFrame(dictlist).tail()

# %% [markdown]
# # Generate list of urls to scrape

# %%
player_list_url = 'https://www.basketball-reference.com/leagues/NBA_2018_per_game.html'
player_list_url2 = 'https://www.basketball-reference.com/leagues/NBA_2017_per_game.html'
player_list_url3 = 'https://www.basketball-reference.com/leagues/NBA_2016_per_game.html'
prev_lists = [clean_html(url) for url in [player_list_url2, player_list_url3] ]          
player_list = clean_html(player_list_url)

# %%
player_links_2018 = {row.a['href'] for row in (player_list.find("table", id='per_game_stats').find_all('tr', attrs={'class':'full_table'}))}
len(player_links_2018)
# Out:
# 540

# %%
all_links = player_links_2018 | other_links
len(all_links)
# Out:
# 689

# %%
urls = ['https://www.basketball-reference.com' + ref for ref in all_links]

# %%
urls[:5]
# Out:
# ['https://www.basketball-reference.com/players/m/millemi01.html',
#  'https://www.basketball-reference.com/players/v/vanvlfr01.html',
#  'https://www.basketball-reference.com/players/c/cartevi01.html',
#  'https://www.basketball-reference.com/players/b/bradlto01.html',
#  'https://www.basketball-reference.com/players/g/greenje02.html']

# %% [markdown]
# # Scrape pages

# %%
def scrape(url):
    """return list of dicts from url"""
    return make_rows(clean_html(url))

# %%
data_list = []
for i, url in enumerate(urls):
    data = scrape(url)
    data_list.extend(data)
    time.sleep(0.5+2*random.random())
    
    #dump data for every 200 players
    if (i+1) % 200 == 0:
        df = pd.DataFrame(data_list)
        with open('players %s.pkl' % (i+1), 'wb') as picklefile:
            pickle.dump(df, picklefile)
        data_list = [] # delete once saved

#dump final set of players
df = pd.DataFrame(data_list)
with open('players_last.pkl', 'wb') as picklefile:
    pickle.dump(df, picklefile)        
    
#642 is a broken page. use urls2 if want to scrape again
# Out:
# Mike Miller
# Fred VanVleet
# Vince Carter
# Tony Bradley
# Jeff Green
# Quincy Pondexter
# Ersan Ilyasova
# Khris Middleton
# Cameron Bairstow
# Arron Afflalo
# Luke Kennard
# Cameron Payne
# Paul Pierce
# Ivan Rabb
# Jrue Holiday
# Brandon Paul
# Andre Miller
# DeMarcus Cousins
# London Perrantes
# Jake Layman
# Julius Randle
# Timofey Mozgov
# Jarell Martin
# Dwight Buycks
# Gary Payton II
# Nikola Jokic
# Tyus Jones
# Tim Duncan
# Mario Chalmers
# Erick Green
# Dario Saric
# Aron Baynes
# Gian Clavell
# PJ Dozier
# Tim Hardaway
# Dakari Johnson
# Alan Williams
# Jerami Grant
# Austin Rivers
# C.J. Watson
# Demetrius Jackson
# Salah Mejri
# Tyler Dorsey
# Tyreke Evans
# Omri Casspi
# Miles Plumlee
# Dorian Finney-Smith
# Sasha Kaun
# Michael Beasley
# Ian Clark
# Mike Dunleavy
# Lucas Nogueira
# Dion Waiters
# Alec Burks
# Coty Clarke
# Anthony Brown
# Elijah Millsap
# Brook Lopez
# Boban Marjanovic
# Rodney Hood
# Jarrett Jack
# Kosta Koufos
# Andrew Nicholson
# James Webb
# Alex Len
# Kirk Hinrich
# Tim Frazier
# J.R. Smith
# Darrell Arthur
# Channing Frye
# Jason Terry
# Jimmy Butler
# Brandon Jennings
# Kadeem Allen
# Tibor Pleiss
# Jordan Bell
# Kyle Lowry
# Ish Smith
# Damien Inglis
# Danilo Gallinari
# Wesley Iwundu
# Wesley Johnson
# Pablo Prigioni
# Al-Farouq Aminu
# Jack Cooley
# Kyle Korver
# Tyler Zeller
# Al Jefferson
# Lamar Patterson
# Ryan Arcidiacono
# Anthony Morrow
# Furkan Korkmaz
# Joel Anthony
# Jonas Jerebko
# Jawun Evans
# Tony Parker
# Jaylen Morris
# Brandon Ingram
# Leandro Barbosa
# Mike Scott
# Udonis Haslem
# Briante Weber
# Ramon Sessions
# Thanasis Antetokounmpo
# Nemanja Bjelica
# Jeff Withey
# Nikola Mirotic
# Russ Smith
# Rudy Gobert
# Shayne Whittington
# Marcelo Huertas
# Joel Bolomboy
# Jaylen Brown
# Alex Caruso
# Solomon Hill
# Greivis Vasquez
# Gerald Henderson
# Tim Quarterman
# Jakob Poeltl
# Isaiah Canaan
# Damian Jones
# Frank Ntilikina
# Damion Lee
# Evan Turner
# James Jones
# Jalen Jones
# Eric Gordon
# Emeka Okafor
# Paul Zipser
# Joakim Noah
# Steve Novak
# Bryce Cotton
# James Ennis
# JaMychal Green
# Paul George
# Tobias Harris
# Ryan Kelly
# Norman Powell
# J.J. O'Brien
# Antonius Cleveland
# Marcus Georges-Hunt
# Jorge Gutierrez
# Joe Young
# Tyler Ulis
# Keith Appling
# Quincy Acy
# Shane Larkin
# Damien Wilkins
# Jamal Murray
# Jonas Valanciunas
# Mindaugas Kuzminskas
# Luis Scola
# Cleanthony Early
# Josh Smith
# Gerald Green
# Aaron Gordon
# Vander Blue
# Bradley Beal
# Chandler Parsons
# Emmanuel Mudiay
# Nikola Vucevic
# Cliff Alexander
# Danny Green
# Patrick Patterson
# Timothe Luwawu-Cabarrot
# Marquese Chriss
# K.J. McDaniels
# Archie Goodwin
# Joe Harris
# D'Angelo Russell
# Troy Daniels
# Eric Moreland
# Sergey Karasev
# Adreian Payne
# R.J. Hunter
# Lance Thomas
# Damjan Rudez
# DeMarre Carroll
# Jayson Tatum
# David Stockton
# Serge Ibaka
# Mason Plumlee
# Tyson Chandler
# Bryce Dejean-Jones
# Myke Henry
# Tyrone Wallace
# Alan Anderson
# Markelle Fultz
# T.J. McConnell
# Raul Neto
# Michael Kidd-Gilchrist
# Andrew Goudelock
# Daniel Hamilton
# Thabo Sefolosha
# Tyler Lydon
# Jordan Clarkson
# Davis Bertans
# Kentavious Caldwell-Pope
# Shelvin Mack
# Taurean Prince
# Trevor Ariza
# Jared Cunningham
# Justin Anderson
# Damyean Dotson
# Roy Hibbert
# Deron Williams
# Seth Curry
# Chuck Hayes
# Erik McCree
# Trey McKinney-Jones
# Lou Williams
# Tony Wroten
# Manu Ginobili
# Joe Johnson
# Victor Oladipo
# Lavoy Allen
# Mitch McGary
# Allen Crabbe
# Kent Bazemore
# Thaddeus Young
# Dante Cunningham
# Chris Kaman
# Brandan Wright
# Michael Carter-Williams
# Lauri Markkanen
# David Nwaba
# Andrew White
# Doug McDermott
# Jordan Hill
# Elliot Williams
# Beno Udrih
# Josh Hart
# Daniel Theis
# Rodney McGruder
# Andre Drummond
# Isaiah Whitehead
# Cody Zeller
# Jusuf Nurkic
# Paul Millsap
# Rashad Vaughn
# Josh Huestis
# Lonzo Ball
# Derrick Favors
# Larry Drew II
# James Johnson
# Pascal Siakam
# Langston Galloway
# Alonzo Gee
# Anderson Varejao
# Kevin Garnett
# Marcus Thornton
# Tomas Satoransky
# Gary Harris
# Gordon Hayward
# Luke Kornet
# Alex Poythress
# Joel Embiid
# Jon Leuer
# Elfrid Payton
# Julyan Stone
# Charlie Villanueva
# Steve Blake
# Isaiah Thomas
# John Henson
# Brandon Rush
# Luol Deng
# Jarell Eddie
# Derrick Walton
# J.J. Hickson
# Luc Mbah a Moute
# Patrick McCaw
# Dennis Smith Jr.
# Reggie Bullock
# Henry Ellenson
# Domantas Sabonis
# Malik Beasley
# Nikola Pekovic
# E'Twaun Moore
# Malcolm Miller
# Derrick Rose
# Matt Costello
# Kostas Papanikolaou
# Tyler Cavanaugh
# Anthony Davis
# Monte Morris
# Thomas Robinson
# Brian Roberts
# Nik Stauskas
# Terrance Ferguson
# Boris Diaw
# Kyle O'Quinn
# Malcolm Brogdon
# Delon Wright
# Ricky Rubio
# Patty Mills
# Okaro White
# Malik Monk
# Pau Gasol
# Zach Randolph
# Tayshaun Prince
# Marc Gasol
# George Hill
# Jerian Grant
# Ante Zizic
# Jordan Adams
# Devin Harris
# Andre Iguodala
# Trey Lyles
# Maxi Kleber
# Blake Griffin
# Robert Covington
# Chris Johnson
# Tony Allen
# Ed Davis
# Cory Joseph
# Iman Shumpert
# Dwayne Bacon
# Bruno Caboclo
# James Harden
# Anthony Tolliver
# Marshall Plumlee
# Jerryd Bayless
# Kelly Oubre Jr.
# Jeff Teague
# D.J. Wilson
# Joffrey Lauvergne
# Drew Gooden
# Wesley Matthews
# Mirza Teletovic
# Amar'e Stoudemire
# Shaquille Harrison
# Sindarius Thornwell
# Aaron Harrison
# Caleb Swanigan
# Wayne Ellington
# Bismack Biyombo
# Lou Amundson
# Norris Cole
# Andrew Wiggins
# Josh Richardson
# Phil Pressey
# Dennis Schroder
# Stanley Johnson
# Jamel Artis
# Cole Aldrich
# Steven Adams
# T.J. Warren
# Brice Johnson
# Elton Brand
# Kemba Walker
# Sean Kilpatrick
# Kendrick Perkins
# Matt Bonner
# Jordan Crawford
# Jeremy Lamb
# Mo Williams
# Jabari Bird
# Spencer Dinwiddie
# JaKarr Sampson
# Skal Labissiere
# Lance Stephenson
# Ben Simmons
# Matt Barnes
# Axel Toupane
# Jodie Meeks
# Nate Robinson
# Wade Baldwin
# David Lee
# Caris LeVert
# Yogi Ferrell
# Kristaps Porzingis
# Enes Kanter
# Reggie Hearn
# Russell Westbrook
# Kevin Durant
# Jamil Wilson
# Jordan Mickey
# Edmond Sumner
# Terry Rozier
# J.J. Barea
# Rasual Butler
# Ike Anigbogu
# Clint Capela
# Mario Hezonja
# Thon Maker
# Markel Brown
# Aaron Jackson
# Myles Turner
# Frank Mason III
# Mike James
# Marcus Smart
# Corey Brewer
# Otto Porter
# Metta World Peace
# Marquis Teague
# Darius Miller
# P.J. Tucker
# Henry Sims
# Luis Montero
# Xavier Silas
# Nate Wolters
# LeBron James
# Jacob Wiley
# Eric Bledsoe
# Tony Snell
# Orlando Johnson
# Josh Gray
# Justin Holiday
# Zaza Pachulia
# Bobby Brown
# De'Aaron Fox
# Donovan Mitchell
# Hassan Whiteside
# Darren Collison
# Justin Patton
# Jarnell Stokes
# OG Anunoby
# Kenneth Faried
# Chris Andersen
# Cristiano Felicio
# Malcolm Delaney
# C.J. Williams
# Kevin Seraphin
# Dwight Howard
# J.J. Redick
# Josh Jackson
# Naz Mitrou-Long
# C.J. Miles
# Matt Williams
# Branden Dawson
# Kyle Singler
# Carmelo Anthony
# DeAndre Liggins
# Xavier Munford
# Kevon Looney
# Derrick Williams
# Ryan Anderson
# Jordan Farmar
# Joe Ingles
# Georgios Papagiannis
# Vince Hunter
# Darrun Hilliard
# Bobby Portis
# Duje Dukan
# Ben McLemore
# Nene
# Rudy Gay
# Kobe Bryant
# Quinn Cook
# Matthew Dellavedova
# Monta Ellis
# John Holland
# Goran Dragic
# Bryn Forbes
# Andre Roberson
# Greg Smith
# Zach LaVine
# Nick Young
# Tiago Splitter
# Klay Thompson
# Andrew Bogut
# Jonathan Gibson
# John Wall
# Jonathon Simmons
# Jamal Crawford
# DeMar DeRozan
# Derrick Jones
# Isaiah Taylor
# Kris Dunn
# Lorenzo Brown
# Dante Exum
# Josh Magette
# Stephen Curry
# Marcus Morris
# Walt Lemon, Jr.
# Brandon Bass
# Rakeem Christmas
# Dejounte Murray
# Damian Lillard
# Kay Felder
# Andrea Bargnani
# Trey Burke
# Sonny Weems
# Marcus Paige
# Jordan Hamilton
# Dillon Brooks
# Xavier Rathan-Mayes
# Chinanu Onuaku
# Juan Hernangomez
# Marreese Speights
# Rodney Purvis
# Semi Ojeleye
# Aaron Brooks
# Jason Smith
# Caron Butler
# Devin Booker
# Danuel House
# Anthony Bennett
# Dragan Bender
# Frank Kaminsky
# James Michael McAdoo
# Dirk Nowitzki
# Johnny O'Bryant
# Cedi Osman
# Marco Belinelli
# Robert Sacre
# P.J. Hairston
# Mike Muscala
# Alec Peters
# Bogdan Bogdanovic
# Devin Robinson
# Zach Collins
# Tristan Thompson
# Guerschon Yabusele
# Jared Dudley
# Gorgui Dieng
# Rajon Rondo
# Chris Boucher
# Kris Humphries
# Nicolas Brussino
# Ty Lawson
# Shaun Livingston
# Deyonta Davis
# Larry Nance Jr.
# Terrence Ross
# C.J. Wilcox
# Jameer Nelson
# Raymond Felton
# Chris Bosh
# Ron Baker
# Jeremy Evans
# Edy Tavares
# Shabazz Napier
# Carl Landry
# Kyrie Irving
# Justin Jackson
# Johnathan Motley
# Hollis Thompson
# Richard Jefferson
# Karl-Anthony Towns
# Jabari Parker
# Justin Harper
# Isaiah Hicks
# Brandon Knight
# Pat Connaughton
# Shabazz Muhammad
# Alexis Ajinca
# Omari Johnson
# Kyle Kuzma
# Donatas Motiejunas
# Alfonzo McKinnie
# Nerlens Noel
# Treveon Graham
# Justise Winslow
# Bam Adebayo
# Nicolas Batum
# Ivica Zubac
# Tyler Ennis
# Cheick Diallo
# Sasha Vujacic
# Jae Crowder
# Richaun Holmes
# Evan Fournier
# Jonathan Isaac
# Devyn Marble
# Toney Douglas
# Willy Hernangomez
# Willie Reed
# Torrey Craig
# Kobi Simmons
# Chase Budinger
# Jameel Warney
# Wayne Selden
# Kyle Collinsworth
# Trevor Booker
# Charles Cooke
# JaVale McGee
# Kawhi Leonard
# Davon Reed
# Jahlil Okafor
# Nigel Hayes
# Sam Dekker
# DeJuan Blair
# Rodney Stuckey
# Andre Ingram
# Alex Abrines
# Courtney Lee
# Nick Collison
# Taj Gibson
# Ben Moore
# DeAndre' Bembry
# Dewayne Dedmon
# Garrett Temple
# O.J. Mayo
# Bojan Bogdanovic
# Jose Calderon
# Zhou Qi
# Noah Vonleh
# Milos Teodosic
# Sterling Brown
# Jimmer Fredette
# Avery Bradley
# Maurice Harkless
# Andrew Harrison
# T.J. Leaf
# Donald Sloan
# Mike Conley
# Randy Foye
# Meyers Leonard
# MarShon Brooks
# Jacob Pullen
# Travis Wear
# Jeremy Lin
# Harrison Barnes
# Markieff Morris
# Tyler Johnson
# Christian Wood
# Kendall Marshall
# Jarrett Allen
# Ray McCallum
# Abdel Nader
# Antonio Blakeney
# Ekpe Udoh
# Jeff Ayres
# Ryan Hollins
# Gary Neal
# Buddy Hield
# Luke Babbitt
# LaMarcus Aldridge
# Draymond Green
# Kelly Olynyk
# Glenn Robinson III
# Greg Monroe
# Wilson Chandler
# Nazr Mohammed
# James Young
# Scotty Hopson
# Marcin Gortat
# Dwyane Wade
# Jared Sullinger
# Al Horford
# Dahntay Jones
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-193-5373fc8a6e80> in <module>()
#       1 data_list = []
#       2 for i, url in enumerate(urls):
# ----> 3     data = scrape(url)
#       4     data_list.extend(data)
#       5     time.sleep(0.5+2*random.random())
#
# <ipython-input-130-7a887324a37c> in scrape(url)
#       1 def scrape(url):
#       2     """return list of dicts from url"""
# ----> 3     return make_rows(clean_html(url))
#
# <ipython-input-151-42bb29f01352> in make_rows(soup)
#       3     output: up to 3 rows per player
#       4     r#s means reverse"""
# ----> 5     print(find_name(soup))
#       6     basic_rows = soup.find("table", id="per_game").find('tbody').find_all('tr', attrs={'class':'full_table'}) #basic
#       7     years_exp = len(basic_rows)
#
# <ipython-input-188-12d82410f62a> in find_name(soup)
#       1 def find_name(soup):
#       2     """player name"""
# ----> 3     return soup.find('div', id='meta').find('h1').text
#       4
#       5 def find_height(soup):
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
urls[642]
# Out:
# 'https://www.basketball-reference.com/players/b/bryanth01.html'

# %%
urls2 = urls[:642]+urls[643:] #642 is a broken page
len(urls2)
# Out:
# 688

# %%
#pickle last set of players
for url in urls2[600:]:
    data = scrape(url)
    data_list.extend(data)
    time.sleep(0.5+2*random.random())
    
last = pd.DataFrame(data_list)
with open('players 688.pkl', 'wb') as picklefile:
    pickle.dump(df, picklefile)
# Out:
# Jimmer Fredette
# Avery Bradley
# Maurice Harkless
# Andrew Harrison
# T.J. Leaf
# Donald Sloan
# Mike Conley
# Randy Foye
# Meyers Leonard
# MarShon Brooks
# Jacob Pullen
# Travis Wear
# Jeremy Lin
# Harrison Barnes
# Markieff Morris
# Tyler Johnson
# Christian Wood
# Kendall Marshall
# Jarrett Allen
# Ray McCallum
# Abdel Nader
# Antonio Blakeney
# Ekpe Udoh
# Jeff Ayres
# Ryan Hollins
# Gary Neal
# Buddy Hield
# Luke Babbitt
# LaMarcus Aldridge
# Draymond Green
# Kelly Olynyk
# Glenn Robinson III
# Greg Monroe
# Wilson Chandler
# Nazr Mohammed
# James Young
# Scotty Hopson
# Marcin Gortat
# Dwyane Wade
# Jared Sullinger
# Al Horford
# Dahntay Jones
# Royce O'Neale
# John Collins
# DeAndre Jordan
# Chris Paul
# David West
# Khem Birch
# Ronnie Price
# Amir Johnson
# Montrezl Harrell
# Mangok Mathiang
# CJ McCollum
# Derrick White
# Spencer Hawes
# Tyler Hansbrough
# Omer Asik
# Chris McCullough
# Kyle Anderson
# Marvin Williams
# Dwight Powell
# D.J. Augustin
# Rondae Hollis-Jefferson
# Festus Ezeli
# Tarik Black
# Jason Thompson
# Jordan McRae
# Patrick Beverley
# Josh McRoberts
# Alex Stepheson
# James Anderson
# Terrence Jones
# Georges Niang
# Kevin Martin
# Giannis Antetokounmpo
# Will Barton
# Chris Copeland
# Milton Doyle
# Malachi Richardson
# John Jenkins
# Denzel Valentine
# Troy Williams
# Robin Lopez
# Willie Cauley-Stein
# Cory Jefferson
# Reggie Jackson
# Kevin Love
# Ian Mahinmi

# %% [markdown]
# # Combine scraped data into dataframe

# %%
with open('players 200.pkl', 'rb') as picklefile:
    data1 = pickle.load(picklefile)

# %%
with open('players 400.pkl', 'rb') as picklefile:
    data2 = pickle.load(picklefile)

# %%
with open('players 600.pkl', 'rb') as picklefile:
    data3 = pickle.load(picklefile)

# %%
with open('players 688.pkl', 'rb') as picklefile:
    data4 = pickle.load(picklefile)

# %%
active_since_2016 = pd.concat([data1, data2, data3, data4])

# %%
active_since_2016.columns
# Out:
# Index(['Name', 'Height', 'Weight', 'Draft Position', 'Career Earnings',
#        'Current Season(C)', 'C_Experience', 'C_Age', 'C_Tm', 'C_Lg',
#        ...
#        'Ca_USG%', 'Ca_ ', 'Ca_OWS', 'Ca_DWS', 'Ca_WS', 'Ca_WS/48', 'Ca_OBPM',
#        'Ca_DBPM', 'Ca_BPM', 'Ca_VORP'],
#       dtype='object', length=161)

# %%
active_since_2016.shape
# Out:
# (1950, 161)

# %%
active_since_2016.describe()
# Out:
#             Height       Weight  Draft Position  Career Earnings  \
# count  1950.000000  1950.000000     1950.000000     1.950000e+03
# mean     78.936923   218.988718       17.401026     2.981917e+07
# std       3.403831    26.296624       16.094711     4.649182e+07
# min      69.000000   150.000000        0.000000     0.000000e+00
# 25%      77.000000   200.000000        2.000000     2.052342e+06
# 50%      79.000000   220.000000       14.000000     1.103216e+07
# 75%      81.000000   240.000000       28.000000     3.922704e+07
# max      87.000000   307.000000       60.000000     3.438724e+08
#
#        C_Experience      C_Salary  P_Experience      P_Salary
# count   1950.000000  1.950000e+03   1579.000000  1.579000e+03
# mean       5.581026  5.054074e+06      5.657378  5.096517e+06
# std        4.387742  6.256305e+06      4.205407  5.685953e+06
# min        1.000000  0.000000e+00      1.000000  0.000000e+00
# 25%        2.000000  9.813120e+05      2.000000  1.128300e+06
# 50%        4.000000  2.365560e+06      5.000000  2.978250e+06
# 75%        8.000000  6.500000e+06      8.000000  6.583500e+06
# max       21.000000  3.468255e+07     20.000000  3.096345e+07

# %%
#dataframe check
#active_since_2016.info()
#active_since_2016.dtypes

# %% [markdown]
# ### Cleaning dataframe

# %% [markdown]
# #### Convert numeric columns from string

# %%
col_names = ['C_Experience', 'C_Age', 'C_Tm', 'C_Lg', 'C_Pos', 'C_G', 'C_GS', 'C_MP', 'C_FG', 'C_FGA', 'C_FG%', 'C_3P', 'C_3PA', 'C_3P%', 'C_2P', 'C_2PA', 'C_2P%', 'C_eFG%', 'C_FT', 'C_FTA', 'C_FT%', 'C_ORB', 'C_DRB', 'C_TRB', 'C_AST', 'C_STL', 'C_BLK', 'C_TOV', 'C_PF', 'C_PTS', 'C_Age', 'C_Tm', 'C_Lg', 'C_Pos', 'C_G', 'C_MP', 'C_PER', 'C_TS%', 'C_3PAr', 'C_FTr', 'C_ORB%', 'C_DRB%', 'C_TRB%', 'C_AST%', 'C_STL%', 'C_BLK%', 'C_TOV%', 'C_USG%', 'C_\xa0', 'C_OWS', 'C_DWS', 'C_WS', 'C_WS/48', 'C_\xa0', 'C_OBPM', 'C_DBPM', 'C_BPM', 'C_VORP', 'C_Salary', 'Prev_Season(P)', 'P_Experience', 'P_Age', 'P_Tm', 'P_Lg', 'P_Pos', 'P_G', 'P_GS', 'P_MP', 'P_FG', 'P_FGA', 'P_FG%', 'P_3P', 'P_3PA', 'P_3P%', 'P_2P', 'P_2PA', 'P_2P%', 'P_eFG%', 'P_FT', 'P_FTA', 'P_FT%', 'P_ORB', 'P_DRB', 'P_TRB', 'P_AST', 'P_STL', 'P_BLK', 'P_TOV', 'P_PF', 'P_PTS', 'P_Age', 'P_Tm', 'P_Lg', 'P_Pos', 'P_G', 'P_MP', 'P_PER', 'P_TS%', 'P_3PAr', 'P_FTr', 'P_ORB%', 'P_DRB%', 'P_TRB%', 'P_AST%', 'P_STL%', 'P_BLK%', 'P_TOV%', 'P_USG%', 'P_\xa0', 'P_OWS', 'P_DWS', 'P_WS', 'P_WS/48', 'P_\xa0', 'P_OBPM', 'P_DBPM', 'P_BPM', 'P_VORP', 'P_Salary', 'Ca_Age', 'Ca_Tm', 'Ca_Lg', 'Ca_Pos', 'Ca_G', 'Ca_GS', 'Ca_MP', 'Ca_FG', 'Ca_FGA', 'Ca_FG%', 'Ca_3P', 'Ca_3PA', 'Ca_3P%', 'Ca_2P', 'Ca_2PA', 'Ca_2P%', 'Ca_eFG%', 'Ca_FT', 'Ca_FTA', 'Ca_FT%', 'Ca_ORB', 'Ca_DRB', 'Ca_TRB', 'Ca_AST', 'Ca_STL', 'Ca_BLK', 'Ca_TOV', 'Ca_PF', 'Ca_PTS', 'Ca_Age', 'Ca_Tm', 'Ca_Lg', 'Ca_Pos', 'Ca_G', 'Ca_MP', 'Ca_PER', 'Ca_TS%', 'Ca_3PAr', 'Ca_FTr', 'Ca_ORB%', 'Ca_DRB%', 'Ca_TRB%', 'Ca_AST%', 'Ca_STL%', 'Ca_BLK%', 'Ca_TOV%', 'Ca_USG%', 'Ca_\xa0', 'Ca_OWS', 'Ca_DWS', 'Ca_WS', 'Ca_WS/48', 'Ca_\xa0', 'Ca_OBPM', 'Ca_DBPM', 'Ca_BPM', 'Ca_VORP']

# %%
for col in col_names:
    active_since_2016[col] = pd.to_numeric(active_since_2016[col], errors='ignore')

# %% [markdown]
# #### Remove empty cols

# %%
all_cols = active_since_2016.columns
len(all_cols)
# Out:
# 161

# %%
all_cols[150:161]
# Out:
# Index(['Ca_TOV%', 'Ca_USG%', 'Ca_ ', 'Ca_OWS', 'Ca_DWS', 'Ca_WS', 'Ca_WS/48',
#        'Ca_OBPM', 'Ca_DBPM', 'Ca_BPM', 'Ca_VORP'],
#       dtype='object')

# %%
empty_cols = [col for col in all_cols if '\xa0' in col]
empty_cols
# Out:
# ['C_\xa0', 'P_\xa0', 'Ca_\xa0']

# %%
clean_active = active_since_2016.drop(empty_cols, axis=1)

# %%
clean_active.shape
# Out:
# (1950, 158)

# %%
clean_active.head()
# Out:
#             Name  Height  Weight  Draft Position  Career Earnings  \
# 0    Mike Miller      80     218               5         93176913
# 1    Mike Miller      80     218               5         93176913
# 2    Mike Miller      80     218               5         93176913
# 3  Fred VanVleet      72     195               0           543471
# 4  Fred VanVleet      72     195               0           543471
#
#   Current Season(C)  C_Experience  C_Age C_Tm C_Lg   ...    Ca_TOV%  Ca_USG%  \
# 0           2016-17            17     36  DEN  NBA   ...       14.1     18.2
# 1           2015-16            16     35  DEN  NBA   ...       14.1     18.2
# 2           2014-15            15     34  CLE  NBA   ...       14.1     18.2
# 3           2017-18             2     23  TOR  NBA   ...       11.1     19.4
# 4           2016-17             1     22  TOR  NBA   ...       11.1     19.4
#
#    Ca_OWS  Ca_DWS  Ca_WS  Ca_WS/48  Ca_OBPM  Ca_DBPM  Ca_BPM  Ca_VORP
# 0    39.2    21.6   60.7     0.105      1.5     -0.6     0.9     20.3
# 1    39.2    21.6   60.7     0.105      1.5     -0.6     0.9     20.3
# 2    39.2    21.6   60.7     0.105      1.5     -0.6     0.9     20.3
# 3     2.6     2.4    5.0     0.131      1.0      0.1     1.1      1.4
# 4     2.6     2.4    5.0     0.131      1.0      0.1     1.1      1.4
#
# [5 rows x 158 columns]

# %% [markdown]
# #### Filter for past three seasons only

# %%
three_seasons = ['2015-16', '2016-17', '2017-18']

# %%
last_three = clean_active[clean_active['Current Season(C)'].isin(three_seasons)]

# %%
last_three.shape
# Out:
# (1711, 158)

# %% [markdown]
# # Pickle 'clean' dataframe for analysis

# %%
with open('last_three_seasons.pkl', 'wb') as picklefile:
    pickle.dump(last_three, picklefile)
